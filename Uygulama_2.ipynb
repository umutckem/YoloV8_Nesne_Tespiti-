# %% [markdown]
# Adınız:  Umutcan
#
# Soyadınız: Kemahlı
#
# Okul Numaranız: 2212721050
#
# GitHub Repo Bağlantısı: https://github.com/umutckem/YoloV8_Nesne_Tespiti-.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.7 MB/s eta 0:00:00
# ...

# %%
# YOLOv8 veri seti yapılandırma dosyası
# Bu dosya, modelin eğitim ve doğrulama sırasında
# hangi klasörleri ve sınıfları kullanacağını tanımlar


# %writefile /content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/data.yaml


# Veri setinin ana dizin yolu
path: /content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/dataset


# Eğitim verilerinin bulunduğu dizin
# YOLO, bu dizin altındaki images/train klasörünü kullanır
train: images/train


# Doğrulama (validation) verilerinin bulunduğu dizin
# Eğitim sırasında model performansını ölçmek için kullanılır
val: images/val


# Veri setinde bulunan sınıfların tanımları
# Her sınıfa karşılık gelen sayısal etiketler belirtilir
names:
  0: chair
  1: keyboard
# Out:
# Writing /content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/data.yaml

# %%
# =======================
# YOLOv8 MODELİNİN YÜKLENMESİ
# =======================

# Ultralytics kütüphanesinden YOLO sınıfı içe aktarılır
from ultralytics import YOLO

# ImageNet benzeri büyük veri setleri üzerinde önceden eğitilmiş
# YOLOv8 nano (yolov8n) modeli yüklenir
# Bu model, transfer learning kapsamında başlangıç ağırlıkları sağlar
model = YOLO("yolov8n.pt")


# =======================
# YOLOv8 MODELİNİN EĞİTİLMESİ
# =======================

# Model, belirtilen veri seti ve parametreler kullanılarak eğitilir
model.train(
    # YOLO veri seti yapılandırma dosyasının yolu (data.yaml)
    data="/content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/data.yaml",

    # Eğitim süresi (epoch sayısı)
    epochs=50,

    # Modele verilecek giriş görüntülerinin boyutu (640x640)
    imgsz=640,

    # Her iterasyonda kullanılacak görüntü sayısı
    batch=16,

    # Eğitim çıktılarının (loglar, ağırlıklar, grafikler) kaydedileceği ana dizin
    project="/content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/runs",

    # Bu eğitime ait deney adı
    name="chair_keyboard",

    # Aynı isimde bir deney varsa üzerine yazılmasına izin verir
    exist_ok=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/runs/chair_keyboard/weights/best.pt")

result = model("/content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/test.jpg")[0]
result.show()
# Out:
# image 1/1 /content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/test.jpg: 480x640 1 keyboard, 42.1ms
# Speed: 2.4ms preprocess, 42.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=905x679>

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/runs/chair_keyboard/weights/best.pt")

result = model("/content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/test3.jpg")[0]
result.show()
# Out:
# image 1/1 /content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/test3.jpg: 640x640 1 keyboard, 7.3ms
# Speed: 3.1ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/runs/chair_keyboard/weights/best.pt")

result = model("/content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/test4.jpg")[0]
result.show()
# Out:
# image 1/1 /content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/test4.jpg: 416x640 1 chair, 60.3ms
# Speed: 3.4ms preprocess, 60.3ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=1200x750>

# %%
from IPython.display import Image
Image(filename="/content/drive/MyDrive/Dersler/Makine-Ogrenmesi/Odev/Uygulama-2/runs/chair_keyboard/results.png")
